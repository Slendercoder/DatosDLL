# %% [markdown]
# # Pre-processing data from Division of Linguistic Labor

# %%
import pandas as pd

# %% [markdown]
# ### Creación del DataFrame con el desempeño en rondas de entrenamiento y juego para ambos tratamientos

# %%
data_single = pd.read_csv('paraK_single.csv')
data_single['Treatment'] = 'Single'
data_single.head(2)
# Out:
#           Dyad           Player     Raza  Stage  Round   Object Label Kind  \
# 0  32519-32519  325192931513079  terrier      5      1  C11.jpg     C    C
# 1  32519-32519  325192931513079  terrier      5      1   A1.jpg     C    A
#
#    Correct Treatment
# 0        1    Single
# 1        0    Single

# %%
data_group = pd.read_csv('paraK_group.csv')
data_group['Treatment'] = 'Dyad'
data_group.head(2)
# Out:
#           Dyad           Player   Raza  Stage  Round  Object Label Kind  \
# 0  45981-38174  459819203408978  hound      1      1  B5.jpg     B    B
# 1  45981-38174  459819203408978  hound      1      1  D2.jpg     B    D
#
#    Correct Treatment
# 0        1      Dyad
# 1        0      Dyad

# %%
data = pd.concat([data_single, data_group])
dict_training_game = {5: 'Training rounds', 1:'Training rounds', 6:'Game rounds', 2: 'Game rounds'}
data['Stage'] = data['Stage'].map(dict_training_game)
del data['Object']
data['RazaN'] = data['Raza'].apply(lambda x: 'terrier' if x=='hound' else 'hound')
data['indice'] = data.index
data['Perro'] = data['indice'].apply(lambda x: 'Perro' + str(x%5 +1))
del data['indice']
data = data[['Dyad', 'Player', 'Raza', 'RazaN', 'Stage', 'Round', 'Perro', 'Label', 'Kind', 'Correct', 'Treatment']]
data.columns = ['pareja', 'jugador', 'experto_en', 'novato_en', 'etapa', 'ronda', 'perro', 'clasificacion', 'raza', 'clasificacion_correcta', 'tratamiento']
data.head()
# Out:
#         pareja          jugador experto_en novato_en            etapa  ronda  \
# 0  32519-32519  325192931513079    terrier     hound  Training rounds      1
# 1  32519-32519  325192931513079    terrier     hound  Training rounds      1
# 2  32519-32519  325192931513079    terrier     hound  Training rounds      1
# 3  32519-32519  325192931513079    terrier     hound  Training rounds      1
# 4  32519-32519  325192931513079    terrier     hound  Training rounds      1
#
#     perro clasificacion raza  clasificacion_correcta tratamiento
# 0  Perro1             C    C                       1      Single
# 1  Perro2             C    A                       0      Single
# 2  Perro3             A    A                       1      Single
# 3  Perro4             A    A                       1      Single
# 4  Perro5             A    A                       1      Single

# %%
data.to_csv('performance.csv', index=False)

# %% [markdown]
# ### Creación del DataFrame con los datos de comunicación

# %%
data_comunicacion = pd.read_csv('comunicacion-raw.csv')
#data_comunicacion = data_comunicacion[['Dyad', 'Player', 'Round', 'Perro', 'Kind', 'suposicion', 'Rotulo', 'Recibido', 'Correctitud']]
data_group = data[(data['tratamiento']=='Dyad') & (data['etapa']=='Game rounds')]
#data_group = data_group[['Dyad', 'Expert', 'Novice', 'Player', 'Round', 'Perro', 'Kind', 'Label', 'Correct']]
df1 = pd.merge(data_group, data_comunicacion, how='left', on=['Player', 'Round', 'Perro'])
#df1 = df1[['Dyad_x', 'Expert', 'Novice', 'Player', 'Round', 'Perro', 'Kind_x', 'Label', 'Correct', 'suposicion', 'Rotulo', 'Recibido', 'Correctitud']]
df1['respondido'] = df1['Recibido'].apply(lambda x: 'Si' if (x=='Si') or (x=='No') else 'No')
#df1.columns = ['pareja', 'experto_en', 'novato_en', 'jugador', 'ronda', 'perro', 'raza', 'clasificacion', 'clasificacion_correcta', 'suposicion', 'rotulo_enviado', 'respuesta', 'respuesta_correcta', 'respondido']
df1.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-afd1768e9e56> in <module>
#       3 data_group = data[(data['tratamiento']=='Dyad') & (data['etapa']=='Game rounds')]
#       4 #data_group = data_group[['Dyad', 'Expert', 'Novice', 'Player', 'Round', 'Perro', 'Kind', 'Label', 'Correct']]
# ----> 5 df1 = pd.merge(data_group, data_comunicacion, how='left', on=['Player', 'Round', 'Perro'])
#       6 #df1 = df1[['Dyad_x', 'Expert', 'Novice', 'Player', 'Round', 'Perro', 'Kind_x', 'Label', 'Correct', 'suposicion', 'Rotulo', 'Recibido', 'Correctitud']]
#       7 df1['respondido'] = df1['Recibido'].apply(lambda x: 'Si' if (x=='Si') or (x=='No') else 'No')
#
# /usr/local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# /usr/local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/lib/python3.8/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     994                         right_keys.append(rk)
#     995                     if lk is not None:
# --> 996                         left_keys.append(left._get_label_or_level_values(lk))
#     997                         join_names.append(lk)
#     998                     else:
#
# /usr/local/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'Player'

# %%
reporte_comprension_individual = pd.read_csv('./calificacion_single.csv')
reporte_comprension_individual['Treatment'] = 'Single'
reporte_comprension_individual.columns = ['jugador', 'experto_en', 'GradingA', 'GradingB', 'GradingC', 'GradingD', 'Treatment']
reporte_comprension_individual.head()
# Out:
#            jugador experto_en  GradingA  GradingB  GradingC  GradingD  \
# 0  325192931513079    terrier         4         4         4         4
# 1  571663380480362    terrier         6         5         6         6
# 2  573037277775110      hound         6         5         6         7
# 3  540382156604799    terrier         6         4         6         4
# 4  880772070057086      hound         5         6         5         6
#
#   Treatment
# 0    Single
# 1    Single
# 2    Single
# 3    Single
# 4    Single

# %%
reporte_comprension_parejas = pd.read_csv('./calificacion_group.csv')
reporte_comprension_parejas['Treatment'] = 'Dyad'
reporte_comprension_parejas.columns = ['jugador', 'experto_en', 'GradingA', 'GradingB', 'GradingC', 'GradingD', 'Treatment']
reporte_comprension_parejas.head()
# Out:
#            jugador experto_en  GradingA  GradingB  GradingC  GradingD  \
# 0   38174543864515    terrier         4         3         7         5
# 1  459819203408978      hound         3         6         4         7
# 2  137619579400459    terrier         7         4         7         4
# 3  835804561913525      hound         4         7         4         7
# 4   42404690668940    terrier         5         3         7         7
#
#   Treatment
# 0      Dyad
# 1      Dyad
# 2      Dyad
# 3      Dyad
# 4      Dyad

# %%
reporte_comprension = pd.concat([reporte_comprension_parejas, reporte_comprension_individual])
reporte_comprension.head()
# Out:
#            jugador experto_en  GradingA  GradingB  GradingC  GradingD  \
# 0   38174543864515    terrier         4         3         7         5
# 1  459819203408978      hound         3         6         4         7
# 2  137619579400459    terrier         7         4         7         4
# 3  835804561913525      hound         4         7         4         7
# 4   42404690668940    terrier         5         3         7         7
#
#   Treatment
# 0      Dyad
# 1      Dyad
# 2      Dyad
# 3      Dyad
# 4      Dyad

# %%
reporte_comprension.to_csv('./rep-comprension.csv', index=False)
